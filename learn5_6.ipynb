# %%
# !nvidia-smi
# Out:
# Sat Feb 28 21:50:33 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 576.65                 Driver Version: 576.65         CUDA Version: 12.9     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                  Driver-Model | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 5070 ...  WDDM  |   00000000:01:00.0  On |                  N/A |
# | N/A   66C    P4             12W /   45W |     830MiB /   8151MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0   N/A  N/A             668    C+G   ...Chrome\Application\chrome.exe      N/A      |
# |    0   N/A  N/A            3564    C+G   ...xyewy\ShellExperienceHost.exe      N/A      |
# |    0   N/A  N/A            7440    C+G   ...yb3d8bbwe\WindowsTerminal.exe      N/A      |
# |    0   N/A  N/A           11272    C+G   ...em32\ApplicationFrameHost.exe      N/A      |
# |    0   N/A  N/A           12044    C+G   ..._cw5n1h2txyewy\SearchHost.exe      N/A      |
# |    0   N/A  N/A           12572    C+G   ...ntrolPanel\SystemSettings.exe      N/A      |
# |    0   N/A  N/A           13668    C+G   C:\Windows\explorer.exe               N/A      |
# |    0   N/A  N/A           14764    C+G   ...ffice6\promecefpluginhost.exe      N/A      |
# |    0   N/A  N/A           16404    C+G   ...y\StartMenuExperienceHost.exe      N/A      |
# |    0   N/A  N/A           17148    C+G   ...indows\System32\ShellHost.exe      N/A      |
# |    0   N/A  N/A           19580    C+G   ...mba6cd70vzyy\ArmouryCrate.exe      N/A      |
# |    0   N/A  N/A           20244    C+G   ....0.3800.82\msedgewebview2.exe      N/A      |
# |    0   N/A  N/A           21164    C+G   ...App_cw5n1h2txyewy\LockApp.exe      N/A      |
# |    0   N/A  N/A           22084    C+G   ...8bbwe\PhoneExperienceHost.exe      N/A      |
# |    0   N/A  N/A           23976    C+G   ...8wekyb3d8bbwe\XboxPcAppFT.exe      N/A      |
# |    0   N/A  N/A           24948    C+G   ...5n1h2txyewy\TextInputHost.exe      N/A      |
# |    0   N/A  N/A           26160    C+G   ...adeonsoftware\AMDRSSrcExt.exe      N/A      |
# |    0   N/A  N/A           27252    C+G   ...t\Edge\Application\msedge.exe      N/A      |
# +-----------------------------------------------------------------------------------------+

# %%
import torch
from torch import nn
torch.device('cpu'),torch.cuda.device('cuda'),torch.cuda.device('cuda:1')
# Out:
# (device(type='cpu'),
#  <torch.cuda.device at 0x1b78645c9a0>,
#  <torch.cuda.device at 0x1b78645c8b0>)

# %%
torch.cuda.device_count()
# Out:
# 0

# %%
# !nvidia-smi
# Out:
# Sun Mar  1 17:06:39 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 576.65                 Driver Version: 576.65         CUDA Version: 12.9     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                  Driver-Model | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 5070 ...  WDDM  |   00000000:01:00.0  On |                  N/A |
# | N/A   52C    P2             10W /   61W |     849MiB /   8151MiB |      1%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0   N/A  N/A            3468    C+G   ...indows\System32\ShellHost.exe      N/A      |
# |    0   N/A  N/A           13444    C+G   C:\Windows\explorer.exe               N/A      |
# |    0   N/A  N/A           14260    C+G   ...8wekyb3d8bbwe\XboxPcAppFT.exe      N/A      |
# |    0   N/A  N/A           15340    C+G   ...8bbwe\PhoneExperienceHost.exe      N/A      |
# |    0   N/A  N/A           16372    C+G   ...yb3d8bbwe\WindowsTerminal.exe      N/A      |
# |    0   N/A  N/A           17152    C+G   ...y\StartMenuExperienceHost.exe      N/A      |
# |    0   N/A  N/A           17176    C+G   ..._cw5n1h2txyewy\SearchHost.exe      N/A      |
# |    0   N/A  N/A           17356    C+G   ...t\Edge\Application\msedge.exe      N/A      |
# |    0   N/A  N/A           20248    C+G   ....0.3800.82\msedgewebview2.exe      N/A      |
# |    0   N/A  N/A           20952    C+G   ...App_cw5n1h2txyewy\LockApp.exe      N/A      |
# |    0   N/A  N/A           22036    C+G   ...Chrome\Application\chrome.exe      N/A      |
# |    0   N/A  N/A           22420    C+G   ...ntrolPanel\SystemSettings.exe      N/A      |
# |    0   N/A  N/A           22424    C+G   ...em32\ApplicationFrameHost.exe      N/A      |
# |    0   N/A  N/A           22524    C+G   ...ffice6\promecefpluginhost.exe      N/A      |
# |    0   N/A  N/A           25292    C+G   ...5n1h2txyewy\TextInputHost.exe      N/A      |
# |    0   N/A  N/A           25644    C+G   ...adeonsoftware\AMDRSSrcExt.exe      N/A      |
# +-----------------------------------------------------------------------------------------+

# %%
torch.cuda.device_count()
# Out:
# 0

# %%
def try_gpu(i=0):
    if torch.cuda.device_count()>=i+1:
        return torch.device(f'cuda:{i}')
    return torch.device('cpu')

# %%
X=torch.ones(2,3,device=try_gpu())
X
# Out:
# tensor([[1., 1., 1.],
#         [1., 1., 1.]])

# %%
print(f"PyTorch 版本: {torch.__version__}")
# Out:
# PyTorch 版本: 2.8.0+cpu
